# %%
import pandas as pd
df = pd. read_csv("bitcoin_price.csv")
df
# Out:
#               Date     Open     High      Low    Close         Volume  \
# 0     Aug 26, 2017  4372.06  4379.28  4269.52  4352.40  1,511,610,000
# 1     Aug 25, 2017  4332.82  4455.70  4307.35  4371.60  1,727,970,000
# 2     Aug 24, 2017  4137.60  4376.39  4130.26  4334.68  2,037,750,000
# 3     Aug 23, 2017  4089.01  4255.78  4078.41  4151.52  2,369,820,000
# 4     Aug 22, 2017  3998.35  4128.76  3674.58  4100.52  3,764,240,000
# ...            ...      ...      ...      ...      ...            ...
# 1577  May 02, 2013   116.38   125.60    92.28   105.21              -
# 1578  May 01, 2013   139.00   139.89   107.72   116.99              -
# 1579  Apr 30, 2013   144.00   146.93   134.05   139.00              -
# 1580  Apr 29, 2013   134.44   147.49   134.00   144.54              -
# 1581  Apr 28, 2013   135.30   135.98   132.10   134.21              -
#
#           Market Cap
# 0     72,249,100,000
# 1     71,595,100,000
# 2     68,363,900,000
# 3     67,553,000,000
# ...

# %% [markdown]
# ### Let's assume we don't have a date in this case:

# %%
df.drop('Date', axis=1, inplace=True)

# %% [markdown]
# ### This is where, date_range comes to rescue:

# %%
rng = pd.date_range(start="4/28/2013", end="8/26/2017", freq="B")[::-1]
rng
# Out:
# DatetimeIndex(['2017-08-25', '2017-08-24', '2017-08-23', '2017-08-22',
#                '2017-08-21', '2017-08-18', '2017-08-17', '2017-08-16',
#                '2017-08-15', '2017-08-14',
#                ...
#                '2013-05-10', '2013-05-09', '2013-05-08', '2013-05-07',
#                '2013-05-06', '2013-05-03', '2013-05-02', '2013-05-01',
#                '2013-04-30', '2013-04-29'],
#               dtype='datetime64[ns]', length=1130, freq='-1B')

# %%
df.set_index(rng, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-6df781639f25> in <module>
# ----> 1 df.set_index(rng, inplace=True)
#
# ~\anaconda3\envs\tensor_gpu\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\tensor_gpu\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5495                 # ensure_index_from_sequences would not raise for append=False.
#    5496                 raise ValueError(
# -> 5497                     f"Length mismatch: Expected {len(self)} rows, "
#    5498                     f"received array of length {len(arrays[-1])}"
#    5499                 )
#
# ...

# %%
df.drop(df.index[-452:], inplace=True)

# %%
df
# Out:
#          Open     High      Low    Close         Volume      Market Cap
# 0     4372.06  4379.28  4269.52  4352.40  1,511,610,000  72,249,100,000
# 1     4332.82  4455.70  4307.35  4371.60  1,727,970,000  71,595,100,000
# 2     4137.60  4376.39  4130.26  4334.68  2,037,750,000  68,363,900,000
# 3     4089.01  4255.78  4078.41  4151.52  2,369,820,000  67,553,000,000
# 4     3998.35  4128.76  3674.58  4100.52  3,764,240,000  66,051,000,000
# ...       ...      ...      ...      ...            ...             ...
# 1125   594.14   594.57   575.18   585.69     19,316,400   7,765,040,000
# 1126   595.67   598.94   593.43   593.85      7,774,230   7,782,830,000
# 1127   601.54   602.09   593.96   595.81     10,752,900   7,857,510,000
# 1128   601.51   607.07   597.23   601.09     12,279,500   7,854,660,000
# 1129   619.50   620.43   595.57   601.73     20,917,200   8,087,290,000
#
# [1130 rows x 6 columns]

# %%
df.set_index(rng, inplace=True)

# %%
df
# Out:
#                Open     High      Low    Close         Volume      Market Cap
# 2017-08-25  4372.06  4379.28  4269.52  4352.40  1,511,610,000  72,249,100,000
# 2017-08-24  4332.82  4455.70  4307.35  4371.60  1,727,970,000  71,595,100,000
# 2017-08-23  4137.60  4376.39  4130.26  4334.68  2,037,750,000  68,363,900,000
# 2017-08-22  4089.01  4255.78  4078.41  4151.52  2,369,820,000  67,553,000,000
# 2017-08-21  3998.35  4128.76  3674.58  4100.52  3,764,240,000  66,051,000,000
# ...             ...      ...      ...      ...            ...             ...
# 2013-05-03   594.14   594.57   575.18   585.69     19,316,400   7,765,040,000
# 2013-05-02   595.67   598.94   593.43   593.85      7,774,230   7,782,830,000
# 2013-05-01   601.54   602.09   593.96   595.81     10,752,900   7,857,510,000
# 2013-04-30   601.51   607.07   597.23   601.09     12,279,500   7,854,660,000
# 2013-04-29   619.50   620.43   595.57   601.73     20,917,200   8,087,290,000
#
# [1130 rows x 6 columns]

# %%
# %matplotlib inline
df.Close.plot()
# Out:
# <AxesSubplot:>

# %%
df.asfreq('H', method='pad')
# Out:
#                         Open     High      Low    Close         Volume  \
# 2013-04-29 00:00:00   619.50   620.43   595.57   601.73     20,917,200
# 2013-04-29 01:00:00   601.51   607.07   597.23   601.09     12,279,500
# 2013-04-29 02:00:00   601.51   607.07   597.23   601.09     12,279,500
# 2013-04-29 03:00:00   601.51   607.07   597.23   601.09     12,279,500
# 2013-04-29 04:00:00   601.51   607.07   597.23   601.09     12,279,500
# ...                      ...      ...      ...      ...            ...
# 2017-08-24 20:00:00  4372.06  4379.28  4269.52  4352.40  1,511,610,000
# 2017-08-24 21:00:00  4372.06  4379.28  4269.52  4352.40  1,511,610,000
# 2017-08-24 22:00:00  4372.06  4379.28  4269.52  4352.40  1,511,610,000
# 2017-08-24 23:00:00  4372.06  4379.28  4269.52  4352.40  1,511,610,000
# 2017-08-25 00:00:00  4372.06  4379.28  4269.52  4352.40  1,511,610,000
#
#                          Market Cap
# 2013-04-29 00:00:00   8,087,290,000
# 2013-04-29 01:00:00   7,854,660,000
# ...

# %%
rng = pd.date_range(start="1/1/2017", periods=72, freq='H')
rng
# Out:
# DatetimeIndex(['2017-01-01 00:00:00', '2017-01-01 01:00:00',
#                '2017-01-01 02:00:00', '2017-01-01 03:00:00',
#                '2017-01-01 04:00:00', '2017-01-01 05:00:00',
#                '2017-01-01 06:00:00', '2017-01-01 07:00:00',
#                '2017-01-01 08:00:00', '2017-01-01 09:00:00',
#                '2017-01-01 10:00:00', '2017-01-01 11:00:00',
#                '2017-01-01 12:00:00', '2017-01-01 13:00:00',
#                '2017-01-01 14:00:00', '2017-01-01 15:00:00',
#                '2017-01-01 16:00:00', '2017-01-01 17:00:00',
#                '2017-01-01 18:00:00', '2017-01-01 19:00:00',
#                '2017-01-01 20:00:00', '2017-01-01 21:00:00',
#                '2017-01-01 22:00:00', '2017-01-01 23:00:00',
#                '2017-01-02 00:00:00', '2017-01-02 01:00:00',
#                '2017-01-02 02:00:00', '2017-01-02 03:00:00',
#                '2017-01-02 04:00:00', '2017-01-02 05:00:00',
# ...

# %%
import numpy as np
ts = pd.Series(np.random.randint(1,10,len(rng)), index=rng)

# %%
ts
# Out:
# 2017-01-01 00:00:00    9
# 2017-01-01 01:00:00    1
# 2017-01-01 02:00:00    1
# 2017-01-01 03:00:00    9
# 2017-01-01 04:00:00    4
#                       ..
# 2017-01-03 19:00:00    5
# 2017-01-03 20:00:00    5
# 2017-01-03 21:00:00    9
# 2017-01-03 22:00:00    4
# 2017-01-03 23:00:00    9
# Freq: H, Length: 72, dtype: int32
