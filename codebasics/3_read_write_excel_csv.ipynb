# %%
import pandas as pd

# %%
df = pd.read_csv("./data/weather_data.csv", header=8)

# %%
df
# Out:
#       aggregation                                          Maximum  \
# 0       timestamp  Kathmandu Temperature [2 m elevation corrected]
# 1   20210902T0000                                          25.0308
# 2   20210903T0000                                          24.4808
# 3   20210904T0000                                          24.4808
# 4   20210905T0000                                          26.5408
# 5   20210906T0000                                          27.4308
# 6   20210907T0000                                          24.3608
# 7   20210908T0000                                          22.3108
# 8   20210909T0000                                          24.5508
# 9   20210910T0000                                          24.4008
# 10  20210911T0000                                          26.4908
# 11  20210912T0000                                        26.250801
# 12  20210913T0000                                          24.0308
# ...

# %%
df = pd.read_csv("./data/weather_data.csv", nrows=7, na_values=['not available', 'n.a'])
df
# Out:
#      location                Kathmandu              Kathmandu.1  \
# 0         lat                 27.80793                 27.80793
# 1         lon                 85.30983                 85.30983
# 2         asl                 1260.200                 1260.200
# 3    variable              Temperature              Temperature
# 4        unit                       °C                       °C
# 5       level  2 m elevation corrected  2 m elevation corrected
# 6  resolution                    daily                    daily
#
#                Kathmandu.2
# 0                 27.80793
# 1                 85.30983
# 2                 1260.200
# 3              Temperature
# 4                       °C
# 5  2 m elevation corrected
# 6                    daily

# %%
df.to_csv('./data/write_csv.csv')

# %%
df.to_excel('./data/write_excel.xlsx', sheet_name="test", startrow=1, startcol=2, index=False)

# %% [markdown]
# ### We can use writer to write in multiple sheets:

# %%
# with pd.ExcelWriter('stocks_weather,xlsx') as writer:
#     df_stocks.to_excel(writer, sheet_name="stocks")
#     df_weather.to_excel(writer, sheet_name="weater")
