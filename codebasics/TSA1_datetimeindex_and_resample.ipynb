# %%
import pandas as pd
df = pd.read_csv("bitcoin_price.csv", parse_dates=["Date"], index_col="Date")
df.head()
# Out:
#                Open     High      Low    Close         Volume      Market Cap
# Date
# 2017-08-26  4372.06  4379.28  4269.52  4352.40  1,511,610,000  72,249,100,000
# 2017-08-25  4332.82  4455.70  4307.35  4371.60  1,727,970,000  71,595,100,000
# 2017-08-24  4137.60  4376.39  4130.26  4334.68  2,037,750,000  68,363,900,000
# 2017-08-23  4089.01  4255.78  4078.41  4151.52  2,369,820,000  67,553,000,000
# 2017-08-22  3998.35  4128.76  3674.58  4100.52  3,764,240,000  66,051,000,000

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df["2017-01"] # getting all rows in jan 2017
# Out:
# C:\Users\ASUS\anaconda3\envs\tensor_gpu\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
#                Open     High      Low    Close       Volume      Market Cap
# Date
# 2017-01-31   920.96   972.02   920.96   970.40  164,582,000  14,859,700,000
# 2017-01-30   920.15   923.05   919.47   920.38   78,227,300  14,844,900,000
# 2017-01-29   922.07   923.42   919.15   919.50   60,851,700  14,874,000,000
# 2017-01-28   919.81   923.91   919.81   921.59   68,979,600  14,835,800,000
# 2017-01-27   918.36   923.22   915.85   919.75  125,594,000  14,810,400,000
# 2017-01-26   902.39   919.33   902.22   917.59  131,958,000  14,551,200,000
# 2017-01-25   891.92   903.25   891.69   901.54  120,831,000  14,380,700,000
# ...

# %%
df["2017-01"].Close.mean()
# Out:
# C:\Users\ASUS\anaconda3\envs\tensor_gpu\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
# 914.9164516129034

# %%
df["2017-01-01":"2017-01-07"]
# Out:
#                Open     High      Low    Close       Volume      Market Cap
# Date
# 2017-01-07   903.49   908.59   823.56   908.59  279,550,000  14,534,400,000
# 2017-01-06  1014.24  1046.81   883.94   902.20  351,876,000  16,314,100,000
# 2017-01-05  1156.73  1191.10   910.42  1013.38  510,199,000  18,604,000,000
# 2017-01-04  1044.40  1159.42  1044.40  1154.73  344,946,000  16,795,400,000
# 2017-01-03  1021.60  1044.08  1021.60  1043.84  185,168,000  16,426,600,000
# 2017-01-02   998.62  1031.39   996.70  1021.75  222,185,000  16,055,100,000

# %%
df.Close.resample('M').mean()
# Out:
# Date
# 2013-04-30     139.250000
# 2013-05-31     119.993226
# 2013-06-30     107.761333
# 2013-07-31      90.512258
# 2013-08-31     113.905161
# 2013-09-30     130.061667
# 2013-10-31     158.311935
# 2013-11-30     550.420667
# 2013-12-31     800.780968
# 2014-01-31     844.168387
# 2014-02-28     661.618214
# 2014-03-31     592.200323
# 2014-04-30     461.362000
# 2014-05-31     486.651290
# 2014-06-30     615.917333
# 2014-07-31     618.025484
# 2014-08-31     536.087742
# 2014-09-30     445.186333
# 2014-10-31     364.150000
# 2014-11-30     366.100000
# 2014-12-31     341.268387
# 2015-01-31     248.782581
# 2015-02-28     234.153571
# 2015-03-31     269.041290
# 2015-04-30     235.491667
# 2015-05-31     236.996774
# 2015-06-30     238.081000
# 2015-07-31     279.563871
# 2015-08-31     250.734516
# 2015-09-30     233.595333
# 2015-10-31     264.855161
# 2015-11-30     348.883333
# 2015-12-31     424.464516
# 2016-01-31     410.844516
# 2016-02-29     404.408276
# ...

# %%
# %matplotlib inline
df.Close.resample('W').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
