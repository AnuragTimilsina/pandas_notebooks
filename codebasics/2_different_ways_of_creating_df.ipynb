# %%
import pandas as pd

# %%
pd.read_csv("./data/weather_data.csv")
# Out:
#          location                                        Kathmandu  \
# 0             lat                                         27.80793
# 1             lon                                         85.30983
# 2             asl                                         1260.200
# 3        variable                                      Temperature
# 4            unit                                               °C
# 5           level                          2 m elevation corrected
# 6      resolution                                            daily
# 7     aggregation                                          Maximum
# 8       timestamp  Kathmandu Temperature [2 m elevation corrected]
# 9   20210902T0000                                          25.0308
# 10  20210903T0000                                          24.4808
# 11  20210904T0000                                          24.4808
# 12  20210905T0000                                          26.5408
# ...

# %%
#df = pd.read_excel("dskfhsdkfj.xlsx", "Sheet1")

# %%
weather_data = {
    'day': [1, 2, 3],
    'temperature': [25 ,26, 24],
    'windspeed': [3,4,2],
}

df = pd.DataFrame(weather_data)
df
# Out:
#    day  temperature  windspeed
# 0    1           25          3
# 1    2           26          4
# 2    3           24          2

# %%
weather_data = [(1, 32, 6, 'Rain'),
                (2, 35, 7, 'Sunny'),
                (3, 28, 2, 'Snow'),
               ]

df = pd.DataFrame(weather_data, columns=("day", "temperature", "windspeed", "event"))
df
# Out:
#    day  temperature  windspeed  event
# 0    1           32          6   Rain
# 1    2           35          7  Sunny
# 2    3           28          2   Snow

# %%
weather_data = [
    {'day': 1, 'temperature': 32, 'windspeed': 6, 'event':'Rain'},
    {'day':2, 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
]

df = pd.DataFrame(weather_data)
df
# Out:
#    day  temperature  windspeed  event
# 0    1           32          6   Rain
# 1    2           35          7  Sunny

# %% [markdown]
# ### go to pandas IO in docs to know more.
