# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
# ...               ...      ...        ...            ...                 ...
# 64858              16      NaN        NaN            NaN       United States
# 64867             NaN      NaN        NaN            NaN             Morocco
# 64898             NaN      NaN        NaN            NaN            Viet Nam
# 64925             NaN      NaN        NaN            NaN              Poland
# 65112             NaN      NaN        NaN            NaN               Spain
#
#               CurrencyDesc CurrencySymbol  ...                  SurveyEase  \
# Respondent                                 ...
# 1            European Euro            EUR  ...  Neither easy nor difficult
# 2           Pound sterling            GBP  ...                         NaN
# 3                      NaN            NaN  ...  Neither easy nor difficult
# 4             Albanian lek            ALL  ...                         NaN
# 5                      NaN            NaN  ...                        Easy
# ...                    ...            ...  ...                         ...
# 64858                  NaN            NaN  ...                         NaN
# 64867                  NaN            NaN  ...                         NaN
# 64898                  NaN            NaN  ...                         NaN
# 64925                  NaN            NaN  ...                         NaN
# 65112                  NaN            NaN  ...                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
# 4                             NaN    No
# 5                       Too short    No
# ...                           ...   ...
# 64858                         NaN   NaN
# 64867                         NaN   NaN
# 64898                         NaN   NaN
# 64925                         NaN   NaN
# 65112                         NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# ...                                                       ...
# 64858       Computer science, computer engineering, or sof...
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112       Computer science, computer engineering, or sof...
#
#                  WebframeDesireNextYear  \
# Respondent
# 1                          ASP.NET Core
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                  Django;Ruby on Rails
# ...                                 ...
# 64858                               NaN
# 64867                               NaN
# 64898                               NaN
# 64925       Angular;Angular.js;React.js
# 65112               ASP.NET Core;jQuery
#
#                                 WebframeWorkedWith  \
# Respondent
# 1                             ASP.NET;ASP.NET Core
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                    Ruby on Rails
# ...                                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                          NaN
# 65112       Angular;Angular.js;ASP.NET Core;jQuery
#
#                                        WelcomeChange WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year        50.0        36
# 2           Somewhat more welcome now than last year         NaN         7
# 3           Somewhat more welcome now than last year         NaN         4
# 4           Somewhat less welcome now than last year        40.0         7
# 5            Just as welcome now as I felt last year         NaN        15
# ...                                              ...         ...       ...
# 64858                                            NaN         NaN        10
# 64867                                            NaN         NaN       NaN
# 64898                                            NaN         NaN       NaN
# 64925                                            NaN         NaN       NaN
# 65112                                            NaN         NaN       NaN
#
#                 YearsCodePro
# Respondent
# 1                         27
# 2                          4
# 3                        NaN
# 4                          4
# 5                          8
# ...                      ...
# 64858       Less than 1 year
# 64867                    NaN
# 64898                    NaN
# 64925                    NaN
# 65112                    NaN
#
# [64461 rows x 60 columns]

# %%
df.shape
# Out:
# (64461, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
#  12  DevType                       49370 non-null  object
#  13  EdLevel                       57431 non-null  object
#  14  Employment                    63854 non-null  object
#  15  Ethnicity                     45948 non-null  object
#  16  Gender                        50557 non-null  object
#  17  JobFactors                    49349 non-null  object
#  18  JobSat                        45194 non-null  object
#  19  JobSeek                       51727 non-null  object
#  20  LanguageDesireNextYear        54113 non-null  object
#  21  LanguageWorkedWith            57378 non-null  object
#  22  MiscTechDesireNextYear        42379 non-null  object
#  23  MiscTechWorkedWith            40314 non-null  object
#  24  NEWCollabToolsDesireNextYear  47287 non-null  object
#  25  NEWCollabToolsWorkedWith      52883 non-null  object
#  26  NEWDevOps                     42686 non-null  object
#  27  NEWDevOpsImpt                 41732 non-null  object
#  28  NEWEdImpt                     48465 non-null  object
#  29  NEWJobHunt                    42286 non-null  object
#  30  NEWJobHuntResearch            41022 non-null  object
#  31  NEWLearn                      56156 non-null  object
#  32  NEWOffTopic                   50804 non-null  object
#  33  NEWOnboardGood                42623 non-null  object
#  34  NEWOtherComms                 57205 non-null  object
#  35  NEWOvertime                   43231 non-null  object
#  36  NEWPurchaseResearch           37321 non-null  object
#  37  NEWPurpleLink                 54803 non-null  object
#  38  NEWSOSites                    58275 non-null  object
#  39  NEWStuck                      54983 non-null  object
#  40  OpSys                         56228 non-null  object
#  41  OrgSize                       44334 non-null  object
#  42  PlatformDesireNextYear        50605 non-null  object
#  43  PlatformWorkedWith            53843 non-null  object
#  44  PurchaseWhat                  39364 non-null  object
#  45  Sexuality                     43992 non-null  object
#  46  SOAccount                     56805 non-null  object
#  47  SOComm                        56476 non-null  object
#  48  SOPartFreq                    46792 non-null  object
#  49  SOVisitFreq                   56970 non-null  object
#  50  SurveyEase                    51802 non-null  object
#  51  SurveyLength                  51701 non-null  object
#  52  Trans                         49345 non-null  object
#  53  UndergradMajor                50995 non-null  object
#  54  WebframeDesireNextYear        40024 non-null  object
#  55  WebframeWorkedWith            42279 non-null  object
#  56  WelcomeChange                 52683 non-null  object
#  57  WorkWeekHrs                   41151 non-null  float64
#  58  YearsCode                     57684 non-null  object
#  59  YearsCodePro                  46349 non-null  object
# dtypes: float64(4), object(56)
# memory usage: 30.0+ MB

# %%
pd.set_option('display.max_columns',61)
pd.set_option('display.max_rows',61)

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
schema_df.head(10)
# Out:
#                                                     QuestionText
# Column
# Respondent     Randomized respondent ID number (not in order ...
# MainBranch     Which of the following options best describes ...
# Hobbyist                                 Do you code as a hobby?
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# CompFreq        Is that compensation weekly, monthly, or yearly?
# CompTotal      What is your current total compensation (salar...
# ConvertedComp  Salary converted to annual USD salaries using ...
# Country                                       Where do you live?
# CurrencyDesc   Which currency do you use day-to-day? If your ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.loc[1,'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[[1,2,3],'Hobbyist']
# Out:
# Respondent
# 1    Yes
# 2     No
# 3    Yes
# Name: Hobbyist, dtype: object

# %%
#using slicing
df.loc[1:3,'Hobbyist']
# Out:
# Respondent
# 1    Yes
# 2     No
# 3    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[1:3,'Hobbyist':'Employment']
# Out:
#            Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# Respondent
# 1               Yes  NaN         13  Monthly        NaN            NaN
# 2                No  NaN         19      NaN        NaN            NaN
# 3               Yes  NaN         15      NaN        NaN            NaN
#
#                        Country    CurrencyDesc CurrencySymbol  \
# Respondent
# 1                      Germany   European Euro            EUR
# 2               United Kingdom  Pound sterling            GBP
# 3           Russian Federation             NaN            NaN
#
#            DatabaseDesireNextYear                         DatabaseWorkedWith  \
# Respondent
# 1            Microsoft SQL Server  Elasticsearch;Microsoft SQL Server;Oracle
# 2                             NaN                                        NaN
# 3                             NaN                                        NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
#
#                                                    Employment
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN

# %%
df.loc[1]
# Out:
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# DatabaseDesireNextYear                                       Microsoft SQL Server
# DatabaseWorkedWith                      Elasticsearch;Microsoft SQL Server;Oracle
# DevType                         Developer, desktop or enterprise applications;...
# EdLevel                           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                      Independent contractor, freelancer, or self-em...
# Ethnicity                                            White or of European descent
# Gender                                                                        Man
# JobFactors                      Languages, frameworks, and other technologies ...
# JobSat                                                         Slightly satisfied
# JobSeek                              I am not interested in new job opportunities
# LanguageDesireNextYear                                     C#;HTML/CSS;JavaScript
# LanguageWorkedWith                                         C#;HTML/CSS;JavaScript
# MiscTechDesireNextYear                                          .NET Core;Xamarin
# MiscTechWorkedWith                                                 .NET;.NET Core
# NEWCollabToolsDesireNextYear               Microsoft Teams;Microsoft Azure;Trello
# NEWCollabToolsWorkedWith             Confluence;Jira;Slack;Microsoft Azure;Trello
# NEWDevOps                                                                      No
# NEWDevOpsImpt                                                  Somewhat important
# NEWEdImpt                                                        Fairly important
# NEWJobHunt                                                                    NaN
# NEWJobHuntResearch                                                            NaN
# NEWLearn                                                              Once a year
# NEWOffTopic                                                              Not sure
# NEWOnboardGood                                                                NaN
# NEWOtherComms                                                                  No
# NEWOvertime                                      Often: 1-2 days per week or more
# NEWPurchaseResearch             Start a free trial;Ask developers I know/work ...
# NEWPurpleLink                                                              Amused
# NEWSOSites                       Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                        Visit Stack Overflow;Go for a walk or other ph...
# OpSys                                                                     Windows
# OrgSize                                                          2 to 9 employees
# PlatformDesireNextYear             Android;iOS;Kubernetes;Microsoft Azure;Windows
# PlatformWorkedWith                                                        Windows
# PurchaseWhat                                                                  NaN
# Sexuality                                                 Straight / Heterosexual
# SOAccount                                                                      No
# SOComm                                                             No, not at all
# SOPartFreq                                                                    NaN
# SOVisitFreq                                                Multiple times per day
# SurveyEase                                             Neither easy nor difficult
# SurveyLength                                                Appropriate in length
# Trans                                                                          No
# UndergradMajor                  Computer science, computer engineering, or sof...
# WebframeDesireNextYear                                               ASP.NET Core
# WebframeWorkedWith                                           ASP.NET;ASP.NET Core
# WelcomeChange                             Just as welcome now as I felt last year
# WorkWeekHrs                                                                    50
# YearsCode                                                                      36
# YearsCodePro                                                                   27
# Name: 1, dtype: object

# %%
schema_df.loc['Hobbyist','QuestionText']
# Out:
# 'Do you code as a hobby?'

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# EdLevel                       Which of the following best describes the high...
# Employment                    Which of the following best describes your cur...
# Ethnicity                     Which of the following describe you, if any? P...
# Gender                        Which of the following describe you, if any? P...
# Hobbyist                                                Do you code as a hobby?
# JobFactors                    Imagine that you are deciding between two job ...
# JobSat                        How satisfied are you with your current job? (...
# JobSeek                       Which of the following best describes your cur...
# LanguageDesireNextYear        Which programming, scripting, and markup langu...
# LanguageWorkedWith            Which programming, scripting, and markup langu...
# MainBranch                    Which of the following options best describes ...
# MiscTechDesireNextYear        Which other frameworks, libraries, and tools h...
# MiscTechWorkedWith            Which other frameworks, libraries, and tools h...
# NEWCollabToolsDesireNextYear  Which collaboration tools have you done extens...
# NEWCollabToolsWorkedWith      Which collaboration tools have you done extens...
# NEWDevOps                     Does your company have a dedicated DevOps person?
# NEWDevOpsImpt                 How important is the practice of DevOps to sca...
# NEWEdImpt                     How important is a formal education, such as a...
# NEWJobHunt                    In general, what drives you to look for a new ...
# NEWJobHuntResearch            When job searching, how do you learn more abou...
# NEWLearn                      How frequently do you learn a new language or ...
# NEWOffTopic                   Do you think Stack Overflow should relax restr...
# NEWOnboardGood                Do you think your company has a good onboardin...
# NEWOtherComms                 Are you a member of any other online developer...
# NEWOvertime                   How often do you work overtime or beyond the f...
# NEWPurchaseResearch           When buying a new tool or software, how do you...
# NEWPurpleLink                 You search for a coding solution online and th...
# NEWSOSites                    Which of the following Stack Overflow sites ha...
# NEWStuck                      What do you do when you get stuck on a problem...
# OpSys                         What is the primary operating system in which ...
# OrgSize                       Approximately how many people are employed by ...
# PlatformDesireNextYear        Which platforms have you done extensive develo...
# PlatformWorkedWith            Which platforms have you done extensive develo...
# PurchaseWhat                  What level of influence do you, personally, ha...
# Respondent                    Randomized respondent ID number (not in order ...
# SOAccount                                 Do you have a Stack Overflow account?
# SOComm                        Do you consider yourself a member of the Stack...
# SOPartFreq                    How frequently would you say you participate i...
# SOVisitFreq                   How frequently would you say you visit Stack O...
# Sexuality                     Which of the following describe you, if any? P...
# SurveyEase                    How easy or difficult was this survey to compl...
# SurveyLength                  How do you feel about the length of the survey...
# Trans                                                      Are you transgender?
# UndergradMajor                            What was your primary field of study?
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# YearsCode                     Including any education, how many years have y...
# YearsCodePro                  NOT including education, how many years have y...

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 64858   NaN
# 64867   NaN
# 64898   NaN
# 64925   NaN
# 65112   NaN
# Name: SalaryUSD, Length: 64461, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].map({'Yes': True, 'No':False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No':False})

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession     True   NaN
# 2                              I am a developer by profession    False   NaN
# 3                                 I code primarily as a hobby     True   NaN
# 4                              I am a developer by profession     True  25.0
# 5           I used to be a developer by profession, but no...     True  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN     True   NaN
# 64867                                                     NaN     True   NaN
# 64898                                                     NaN     True   NaN
# 64925                                                     NaN     True   NaN
# 65112                                                     NaN     True   NaN
#
#            Age1stCode CompFreq  CompTotal  SalaryUSD             Country  \
# Respondent
# 1                  13  Monthly        NaN        NaN             Germany
# 2                  19      NaN        NaN        NaN      United Kingdom
# 3                  15      NaN        NaN        NaN  Russian Federation
# 4                  18      NaN        NaN        NaN             Albania
# 5                  16      NaN        NaN        NaN       United States
# ...               ...      ...        ...        ...                 ...
# 64858              16      NaN        NaN        NaN       United States
# 64867             NaN      NaN        NaN        NaN             Morocco
# 64898             NaN      NaN        NaN        NaN            Viet Nam
# 64925             NaN      NaN        NaN        NaN              Poland
# 65112             NaN      NaN        NaN        NaN               Spain
#
#               CurrencyDesc CurrencySymbol  \
# Respondent
# 1            European Euro            EUR
# 2           Pound sterling            GBP
# 3                      NaN            NaN
# 4             Albanian lek            ALL
# 5                      NaN            NaN
# ...                    ...            ...
# 64858                  NaN            NaN
# 64867                  NaN            NaN
# 64898                  NaN            NaN
# 64925                  NaN            NaN
# 65112                  NaN            NaN
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                        Microsoft SQL Server
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                            MySQL;PostgreSQL
# ...                                                       ...
# 64858                                                     NaN
# 64867       Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64898                                                     NaN
# 64925         DynamoDB;Elasticsearch;MongoDB;MySQL;PostgreSQL
# 65112                            MariaDB;Microsoft SQL Server
#
#                                            DatabaseWorkedWith  \
# Respondent
# 1                   Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                               MySQL;PostgreSQL;Redis;SQLite
# ...                                                       ...
# 64858                                                     NaN
# 64867       Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64898                                                     NaN
# 64925                                                  Oracle
# 65112               MariaDB;Microsoft SQL Server;MySQL;Oracle
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 64858                                     Senior executive/VP
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
# 4           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                     ...
# 64858       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64867                                                   NaN
# 64898                             Primary/elementary school
# 64925                                                   NaN
# 65112            Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN
# 4                                                         NaN
# 5                                          Employed full-time
# ...                                                       ...
# 64858                                      Employed full-time
# 64867                                      Employed full-time
# 64898                                                     NaN
# 64925                                      Employed full-time
# 65112                                      Employed full-time
#
#                                Ethnicity Gender  \
# Respondent
# 1           White or of European descent    Man
# 2                                    NaN    NaN
# 3                                    NaN    NaN
# 4           White or of European descent    Man
# 5           White or of European descent    Man
# ...                                  ...    ...
# 64858                                NaN    NaN
# 64867                                NaN    NaN
# 64898                                NaN    NaN
# 64925                                NaN    NaN
# 65112                                NaN    NaN
#
#                                                    JobFactors  \
# Respondent
# 1           Languages, frameworks, and other technologies ...
# 2                                                         NaN
# 3                                                         NaN
# 4           Flex time or a flexible schedule;Office enviro...
# 5                                                         NaN
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                            JobSat  \
# Respondent
# 1              Slightly satisfied
# 2               Very dissatisfied
# 3                             NaN
# 4           Slightly dissatisfied
# 5                             NaN
# ...                           ...
# 64858                         NaN
# 64867                         NaN
# 64898                         NaN
# 64925                         NaN
# 65112                         NaN
#
#                                                       JobSeek  \
# Respondent
# 1                I am not interested in new job opportunities
# 2                I am not interested in new job opportunities
# 3                                                         NaN
# 4           I’m not actively looking, but I am open to new...
# 5                                                         NaN
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#                                        LanguageDesireNextYear  \
# Respondent
# 1                                      C#;HTML/CSS;JavaScript
# 2                                                Python;Swift
# 3                                    Objective-C;Python;Swift
# 4                                                         NaN
# 5                                             Java;Ruby;Scala
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                HTML/CSS;Java;JavaScript
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                                            LanguageWorkedWith  \
# Respondent
# 1                                      C#;HTML/CSS;JavaScript
# 2                                            JavaScript;Swift
# 3                                    Objective-C;Python;Swift
# 4                                                         NaN
# 5                                           HTML/CSS;Ruby;SQL
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                                HTML/CSS
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
# 4                                        NaN                NaN
# 5                               Ansible;Chef            Ansible
# ...                                      ...                ...
# 64858                                    NaN                NaN
# 64867                                    NaN                NaN
# 64898                                    NaN                NaN
# 64925                                Node.js                NaN
# 65112                      .NET Core;Xamarin     .NET;.NET Core
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
# 4                                              NaN
# 5            Github;Google Suite (Docs, Meet, etc)
# ...                                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                Github;Gitlab
# 65112                       Github;Microsoft Teams
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1                Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                         Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                         NaN       NaN
# 4                                                         NaN        No
# 5           Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
# ...                                                       ...       ...
# 64858                                                     NaN       NaN
# 64867                                                     NaN       NaN
# 64898                                                     NaN       NaN
# 64925                   Confluence;Jira;Slack;Microsoft Teams       NaN
# 65112                                                  Github       NaN
#
#                  NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 1           Somewhat important                    Fairly important
# 2                          NaN                    Fairly important
# 3                          NaN                                 NaN
# 4                          NaN  Not at all important/not necessary
# 5                          NaN                      Very important
# ...                        ...                                 ...
# 64858                      NaN                      Very important
# 64867                      NaN                                 NaN
# 64898                      NaN                                 NaN
# 64925                      NaN                                 NaN
# 65112                      NaN                Critically important
#
#                                                    NEWJobHunt  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Curious about other opportunities;Wanting to w...
# 5                                                         NaN
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#            NEWJobHuntResearch       NEWLearn NEWOffTopic NEWOnboardGood  \
# Respondent
# 1                         NaN    Once a year    Not sure            NaN
# 2                         NaN    Once a year    Not sure            NaN
# 3                         NaN  Once a decade         NaN            NaN
# 4                         NaN    Once a year    Not sure            Yes
# 5                         NaN    Once a year          No            NaN
# ...                       ...            ...         ...            ...
# 64858                     NaN  Once a decade         NaN            NaN
# 64867                     NaN            NaN         NaN            NaN
# 64898                     NaN            NaN         NaN            NaN
# 64925                     NaN    Once a year         NaN            NaN
# 65112                     NaN    Once a year         NaN            NaN
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 1                     No                   Often: 1-2 days per week or more
# 2                     No                                                NaN
# 3                     No                                                NaN
# 4                    Yes  Occasionally: 1-2 days per quarter but less th...
# 5                    Yes                                                NaN
# ...                  ...                                                ...
# 64858                NaN                                                NaN
# 64867                NaN                                                NaN
# 64898                NaN                                                NaN
# 64925                NaN                                                NaN
# 65112                NaN                                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           Start a free trial;Ask developers I know/work ...
# ...                                                       ...
# 64858                                      Start a free trial
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                      Start a free trial
# 65112       Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 1                      Amused
# 2                      Amused
# 3                         NaN
# 4                         NaN
# 5           Hello, old friend
# ...                       ...
# 64858                  Amused
# 64867                     NaN
# 64898                     NaN
# 64925       Hello, old friend
# 65112             Indifferent
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
# 4           Stack Overflow (public Q&A for anyone who code...
# 5           Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 64858        Stack Overflow (public Q&A for anyone who codes)
# 64867                                                     NaN
# 64898                                                     NaN
# 64925        Stack Overflow (public Q&A for anyone who codes)
# 65112                                                     NaN
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
# ...                                                       ...          ...
# 64858                               Call a coworker or friend      Windows
# 64867                                                     NaN          NaN
# 64898                                                     NaN          NaN
# 64925          Call a coworker or friend;Visit Stack Overflow      Windows
# 65112       Meditate;Visit Stack Overflow;Go for a walk or...      Windows
#
#                              OrgSize  \
# Respondent
# 1                   2 to 9 employees
# 2           1,000 to 4,999 employees
# 3                                NaN
# 4                 20 to 99 employees
# 5                                NaN
# ...                              ...
# 64858                            NaN
# 64867                            NaN
# 64898                            NaN
# 64925                            NaN
# 65112                            NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                      Arduino;Linux;Raspberry Pi;Windows
#
#                                     PlatformWorkedWith  \
# Respondent
# 1                                              Windows
# 2                                                  iOS
# 3                                                  NaN
# 4                                                  NaN
# 5                       AWS;Docker;Linux;MacOS;Windows
# ...                                                ...
# 64858                                              NaN
# 64867                                              NaN
# 64898                                              NaN
# 64925                                    Linux;Windows
# 65112       Android;Arduino;Linux;Raspberry Pi;Windows
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 1                                        NaN  Straight / Heterosexual
# 2              I have little or no influence                      NaN
# 3                                        NaN                      NaN
# 4           I have a great deal of influence  Straight / Heterosexual
# 5                                        NaN  Straight / Heterosexual
# ...                                      ...                      ...
# 64858                                    NaN                      NaN
# 64867                                    NaN                      NaN
# 64898                                    NaN                      NaN
# 64925                                    NaN                      NaN
# 65112                                    NaN                      NaN
#
#            SOAccount           SOComm                           SOPartFreq  \
# Respondent
# 1                 No   No, not at all                                  NaN
# 2                Yes  Yes, definitely  Less than once per month or monthly
# 3                Yes    Yes, somewhat      A few times per month or weekly
# 4                Yes  Yes, definitely      A few times per month or weekly
# 5                Yes    Yes, somewhat  Less than once per month or monthly
# ...              ...              ...                                  ...
# 64858            NaN              NaN                                  NaN
# 64867            NaN              NaN                                  NaN
# 64898            NaN              NaN                                  NaN
# 64925            NaN              NaN                                  NaN
# 65112            NaN              NaN                                  NaN
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 1                    Multiple times per day  Neither easy nor difficult
# 2                    Multiple times per day                         NaN
# 3                     Daily or almost daily  Neither easy nor difficult
# 4                    Multiple times per day                         NaN
# 5           A few times per month or weekly                        Easy
# ...                                     ...                         ...
# 64858                                   NaN                         NaN
# 64867                                   NaN                         NaN
# 64898                                   NaN                         NaN
# 64925                                   NaN                         NaN
# 65112                                   NaN                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
# 4                             NaN    No
# 5                       Too short    No
# ...                           ...   ...
# 64858                         NaN   NaN
# 64867                         NaN   NaN
# 64898                         NaN   NaN
# 64925                         NaN   NaN
# 65112                         NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# ...                                                       ...
# 64858       Computer science, computer engineering, or sof...
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112       Computer science, computer engineering, or sof...
#
#                  WebframeDesireNextYear  \
# Respondent
# 1                          ASP.NET Core
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                  Django;Ruby on Rails
# ...                                 ...
# 64858                               NaN
# 64867                               NaN
# 64898                               NaN
# 64925       Angular;Angular.js;React.js
# 65112               ASP.NET Core;jQuery
#
#                                 WebframeWorkedWith  \
# Respondent
# 1                             ASP.NET;ASP.NET Core
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                    Ruby on Rails
# ...                                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                          NaN
# 65112       Angular;Angular.js;ASP.NET Core;jQuery
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
# 4           Somewhat less welcome now than last year         40.0         7
# 5            Just as welcome now as I felt last year          NaN        15
# ...                                              ...          ...       ...
# 64858                                            NaN          NaN        10
# 64867                                            NaN          NaN       NaN
# 64898                                            NaN          NaN       NaN
# 64925                                            NaN          NaN       NaN
# 65112                                            NaN          NaN       NaN
#
#                 YearsCodePro
# Respondent
# 1                         27
# 2                          4
# 3                        NaN
# 4                          4
# 5                          8
# ...                      ...
# 64858       Less than 1 year
# 64867                    NaN
# 64898                    NaN
# 64925                    NaN
# 65112                    NaN
#
# [64461 rows x 60 columns]

# %%
df.sort_values(by='Country',inplace=True)

# %%
df[['Country','SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 8631        Afghanistan        NaN
# 25001       Afghanistan        NaN
# 58171       Afghanistan        NaN
# 42668       Afghanistan        NaN
# 51509       Afghanistan    20220.0
# 37951       Afghanistan        NaN
# 28374       Afghanistan   130000.0
# 7616        Afghanistan        NaN
# 43966       Afghanistan        NaN
# 62698       Afghanistan        NaN
# 51532       Afghanistan        NaN
# 36574       Afghanistan        NaN
# 43946       Afghanistan        NaN
# 65381       Afghanistan  1000000.0
# 38672       Afghanistan   231192.0
# 35753       Afghanistan      780.0
# 43808       Afghanistan        NaN
# 37159       Afghanistan        NaN
# 44555       Afghanistan        NaN
# 35687       Afghanistan        NaN
# 37605       Afghanistan        NaN
# 44556       Afghanistan        NaN
# 23798       Afghanistan        NaN
# 42188       Afghanistan        NaN
# 65456       Afghanistan  1000000.0
# 44697       Afghanistan        NaN
# 60507       Afghanistan        NaN
# 898         Afghanistan        NaN
# 51900       Afghanistan        NaN
# 35179       Afghanistan        NaN
# 2932        Afghanistan    16335.0
# 55019       Afghanistan        NaN
# 15422       Afghanistan    18000.0
# 46844       Afghanistan        NaN
# 45481       Afghanistan        NaN
# 51862       Afghanistan    20950.0
# 63848       Afghanistan    23328.0
# 35656       Afghanistan        NaN
# 33878       Afghanistan     1860.0
# 26575       Afghanistan        NaN
# 37601       Afghanistan        NaN
# 9839        Afghanistan    23328.0
# 57269       Afghanistan    10884.0
# 29893       Afghanistan        NaN
# 45409       Afghanistan        NaN
# 51683       Afghanistan        NaN
# 30608       Afghanistan        NaN
# 26775       Afghanistan     8016.0
# 39217       Afghanistan        NaN
# 30568       Afghanistan     5448.0

# %%
df.sort_values(by=['Country','SalaryUSD'], ascending=[False, False], inplace=True)

# %%
df[['Country','SalaryUSD']].head(50)
# Out:
#              Country  SalaryUSD
# Respondent
# 9490        Zimbabwe   180000.0
# 24779       Zimbabwe    30000.0
# 41353       Zimbabwe    24000.0
# 19053       Zimbabwe    18000.0
# 26318       Zimbabwe    10000.0
# 31260       Zimbabwe     7200.0
# 14181       Zimbabwe     7200.0
# 25843       Zimbabwe     4320.0
# 36904       Zimbabwe     4200.0
# 62911       Zimbabwe     3600.0
# 39007       Zimbabwe     1200.0
# 56060       Zimbabwe        NaN
# 24513       Zimbabwe        NaN
# 15319       Zimbabwe        NaN
# 33918       Zimbabwe        NaN
# 61917       Zimbabwe        NaN
# 12810       Zimbabwe        NaN
# 46578       Zimbabwe        NaN
# 9156        Zimbabwe        NaN
# 17220       Zimbabwe        NaN
# 55609       Zimbabwe        NaN
# 17111       Zimbabwe        NaN
# 38892       Zimbabwe        NaN
# 55739       Zimbabwe        NaN
# 52068       Zimbabwe        NaN
# 22593       Zimbabwe        NaN
# 20367       Zimbabwe        NaN
# 12039       Zimbabwe        NaN
# 64506       Zimbabwe        NaN
# 47202       Zimbabwe        NaN
# 64129       Zimbabwe        NaN
# 21759         Zambia    60000.0
# 56632         Zambia    19632.0
# 50489         Zambia     5452.0
# 42242         Zambia     1632.0
# 57445         Zambia      816.0
# 56495         Zambia        NaN
# 59964         Zambia        NaN
# 25833         Zambia        NaN
# 14212         Zambia        NaN
# 38292         Zambia        NaN
# 26707         Zambia        NaN
# 59937         Zambia        NaN
# 64551         Zambia        NaN
# 64771         Zambia        NaN
# 22520         Zambia        NaN
# 62290         Zambia        NaN
# 55645         Zambia        NaN
# 63041         Zambia        NaN
# 8776          Zambia        NaN

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 1793     2000000.0
# 3072     2000000.0
# 3045     2000000.0
# 1413     2000000.0
# 3261     2000000.0
# 57863    2000000.0
# 3236     2000000.0
# 3179     2000000.0
# 3177     2000000.0
# 1589     2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1793                           I am a developer by profession     True  27.0
# 3072                           I am a developer by profession     True  32.0
# 3045                           I am a developer by profession     True  35.0
# 1413                           I am a developer by profession     True  25.0
# 3261                           I am a developer by profession     True  34.0
# 57863                          I am a developer by profession     True  22.0
# 3236                           I am a developer by profession    False  31.0
# 3179                           I am a developer by profession     True  30.0
# 3177                           I am a developer by profession    False  44.0
# 1589        I am not primarily a developer, but I write co...    False  59.0
#
#            Age1stCode CompFreq  CompTotal  SalaryUSD        Country  \
# Respondent
# 1793               16   Weekly   120000.0  2000000.0  United States
# 3072               22   Weekly   102000.0  2000000.0  United States
# 3045               12   Weekly   100000.0  2000000.0  United States
# 1413               12   Weekly    41000.0  2000000.0  United States
# 3261               23   Weekly   115000.0  2000000.0  United States
# 57863              17   Weekly    90000.0  2000000.0  United States
# 3236               25   Weekly    73000.0  2000000.0  United States
# 3179               13   Weekly    79000.0  2000000.0  United States
# 3177                9   Weekly   160000.0  2000000.0  United States
# 1589               45   Weekly    94000.0  2000000.0  United States
#
#                     CurrencyDesc CurrencySymbol  \
# Respondent
# 1793        United States dollar            USD
# 3072        United States dollar            USD
# 3045        United States dollar            USD
# 1413        United States dollar            USD
# 3261        United States dollar            USD
# 57863       United States dollar            USD
# 3236        United States dollar            USD
# 3179        United States dollar            USD
# 3177        United States dollar            USD
# 1589        United States dollar            USD
#
#                             DatabaseDesireNextYear  \
# Respondent
# 1793                      MariaDB;PostgreSQL;Redis
# 3072                                       MongoDB
# 3045        MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# 1413                    Microsoft SQL Server;MySQL
# 3261                          DynamoDB;MySQL;Redis
# 57863                                      MongoDB
# 3236                          Microsoft SQL Server
# 3179                          Microsoft SQL Server
# 3177                                           NaN
# 1589                          Microsoft SQL Server
#
#                                            DatabaseWorkedWith  \
# Respondent
# 1793                              Elasticsearch;Oracle;SQLite
# 3072                               Microsoft SQL Server;Redis
# 3045        DynamoDB;MariaDB;Microsoft SQL Server;MongoDB;...
# 1413                               Microsoft SQL Server;MySQL
# 3261                                         DynamoDB;MongoDB
# 57863                                                   MySQL
# 3236                                     Microsoft SQL Server
# 3179                                     Microsoft SQL Server
# 3177                               Microsoft SQL Server;MySQL
# 1589                                     Microsoft SQL Server
#
#                                                       DevType  \
# Respondent
# 1793                                      Developer, back-end
# 3072        Data scientist or machine learning specialist;...
# 3045        Developer, back-end;Developer, desktop or ente...
# 1413        Database administrator;Designer;Developer, bac...
# 3261        Data scientist or machine learning specialist;...
# 57863           Developer, desktop or enterprise applications
# 3236        Developer, back-end;Developer, front-end;Devel...
# 3179                                    Developer, full-stack
# 3177        Developer, back-end;Developer, front-end;Devel...
# 1589        Data or business analyst;Data scientist or mac...
#
#                                                       EdLevel  \
# Respondent
# 1793             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3072          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3045             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1413        Some college/university study without earning ...
# 3261             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 57863            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3236             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3179             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3177             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1589                                                      NaN
#
#                                                    Employment  \
# Respondent
# 1793                                       Employed full-time
# 3072                                       Employed full-time
# 3045                                       Employed full-time
# 1413                                       Employed full-time
# 3261        Independent contractor, freelancer, or self-em...
# 57863                                      Employed full-time
# 3236                                       Employed full-time
# 3179                                       Employed full-time
# 3177                                       Employed full-time
# 1589                                       Employed full-time
#
#                                                     Ethnicity  \
# Respondent
# 1793                             White or of European descent
# 3072                             White or of European descent
# 3045                             White or of European descent
# 1413                             White or of European descent
# 3261        White or of European descent;South Asian;Multi...
# 57863                             Black or of African descent
# 3236                             White or of European descent
# 3179                             White or of European descent
# 3177                             White or of European descent
# 1589                             White or of European descent
#
#                                                        Gender  \
# Respondent
# 1793                                                      Man
# 3072                                                      Man
# 3045                                                      Man
# 1413        Non-binary, genderqueer, or gender non-conforming
# 3261                                                      Man
# 57863                                                     Man
# 3236                                                      Man
# 3179                                                      Man
# 3177                                                      Man
# 1589                                                    Woman
#
#                                                    JobFactors  \
# Respondent
# 1793        Languages, frameworks, and other technologies ...
# 3072        Flex time or a flexible schedule;Languages, fr...
# 3045        Office environment or company culture;Opportun...
# 1413        Flex time or a flexible schedule;How widely us...
# 3261        Languages, frameworks, and other technologies ...
# 57863       Flex time or a flexible schedule;Languages, fr...
# 3236        How widely used or impactful my work output wo...
# 3179        Industry that I’d be working in;Languages, fra...
# 3177        Flex time or a flexible schedule;Remote work o...
# 1589        Flex time or a flexible schedule;Remote work o...
#
#                            JobSat  \
# Respondent
# 1793           Slightly satisfied
# 3072               Very satisfied
# 3045        Slightly dissatisfied
# 1413           Slightly satisfied
# 3261            Very dissatisfied
# 57863       Slightly dissatisfied
# 3236               Very satisfied
# 3179           Slightly satisfied
# 3177        Slightly dissatisfied
# 1589        Slightly dissatisfied
#
#                                                       JobSeek  \
# Respondent
# 1793        I’m not actively looking, but I am open to new...
# 3072        I’m not actively looking, but I am open to new...
# 3045                          I am actively looking for a job
# 1413        I’m not actively looking, but I am open to new...
# 3261                          I am actively looking for a job
# 57863       I’m not actively looking, but I am open to new...
# 3236             I am not interested in new job opportunities
# 3179        I’m not actively looking, but I am open to new...
# 3177        I’m not actively looking, but I am open to new...
# 1589        I’m not actively looking, but I am open to new...
#
#                                        LanguageDesireNextYear  \
# Respondent
# 1793                                             Dart;Go;Ruby
# 3072                                           C#;Python;Rust
# 3045        Bash/Shell/PowerShell;C#;C++;Go;HTML/CSS;Java;...
# 1413        Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 3261                          HTML/CSS;Java;JavaScript;Python
# 57863                             Go;JavaScript;Kotlin;Python
# 3236                        C#;C++;HTML/CSS;JavaScript;Python
# 3179                                       C#;Java;TypeScript
# 3177                                    JavaScript;TypeScript
# 1589                                             Python;R;SQL
#
#                                            LanguageWorkedWith  \
# Respondent
# 1793        Bash/Shell/PowerShell;C++;HTML/CSS;Python;Rust...
# 3072                                                C#;Python
# 3045        Bash/Shell/PowerShell;C;C#;C++;Go;HTML/CSS;Jav...
# 1413        Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 3261                          HTML/CSS;Java;JavaScript;Python
# 57863                                              C;C++;Java
# 3236                      C;C#;C++;HTML/CSS;JavaScript;Python
# 3179        C#;HTML/CSS;Java;JavaScript;Objective-C;SQL;Sw...
# 3177        Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 1589                                                R;SQL;VBA
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 1793                                                      NaN
# 3072        .NET Core;Cordova;Pandas;TensorFlow;Torch/PyTorch
# 3045        .NET;.NET Core;Apache Spark;Hadoop;Unity 3D;Un...
# 1413                                                      NaN
# 3261                                                      NaN
# 57863                                                     NaN
# 3236                                           .NET;.NET Core
# 3179                         .NET Core;Unity 3D;Unreal Engine
# 3177                                                  Node.js
# 1589                                                      NaN
#
#                                            MiscTechWorkedWith  \
# Respondent
# 1793                                                  Ansible
# 3072                                         .NET Core;Pandas
# 3045        .NET;.NET Core;Apache Spark;Hadoop;Node.js;Uni...
# 1413                                                      NaN
# 3261                                                      NaN
# 57863                                                     NaN
# 3236                                           .NET;.NET Core
# 3179                                   .NET;.NET Core;Node.js
# 3177                                                  Node.js
# 1589                                                      NaN
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 1793                                                      NaN
# 3072        Confluence;Gitlab;Microsoft Teams;Microsoft Az...
# 3045        Github;Microsoft Teams;Microsoft Azure;Google ...
# 1413                                              Jira;Github
# 3261        Confluence;Jira;Github;Slack;Google Suite (Doc...
# 57863                     Confluence;Jira;Github;Gitlab;Slack
# 3236        Confluence;Github;Microsoft Teams;Microsoft Az...
# 3179                   Confluence;Jira;Github;Microsoft Teams
# 3177                                                      NaN
# 1589                                          Microsoft Teams
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1793                   Confluence;Jira;Github;Microsoft Teams       Yes
# 3072                        Confluence;Gitlab;Microsoft Azure       Yes
# 3045        Github;Slack;Microsoft Teams;Microsoft Azure;G...        No
# 1413                                                   Github        No
# 3261        Confluence;Jira;Github;Slack;Google Suite (Doc...       Yes
# 57863                           Confluence;Jira;Github;Gitlab  Not sure
# 3236        Confluence;Github;Microsoft Teams;Microsoft Az...       Yes
# 3179                   Confluence;Jira;Github;Microsoft Teams        No
# 3177         Jira;Github;Slack;Google Suite (Docs, Meet, etc)        No
# 1589                                          Microsoft Teams        No
#
#                   NEWDevOpsImpt             NEWEdImpt  \
# Respondent
# 1793                    Neutral        Very important
# 3072        Extremely important        Very important
# 3045         Not very important        Very important
# 1413                    Neutral      Fairly important
# 3261        Extremely important  Critically important
# 57863       Extremely important        Very important
# 3236        Extremely important  Critically important
# 3179         Somewhat important        Very important
# 3177         Somewhat important    Somewhat important
# 1589                    Neutral      Fairly important
#
#                                                    NEWJobHunt  \
# Respondent
# 1793        Just because;Having a bad day (or week or mont...
# 3072        Curious about other opportunities;Growth or le...
# 3045        Having a bad day (or week or month) at work;Wa...
# 1413        Curious about other opportunities;Better compe...
# 3261        Having a bad day (or week or month) at work;Cu...
# 57863       Better compensation;Wanting to work with new t...
# 3236        Having a bad day (or week or month) at work;Cu...
# 3179        Just because;Curious about other opportunities...
# 3177        Having a bad day (or week or month) at work;Cu...
# 1589        Trouble with my direct manager;Wanting to work...
#
#                                            NEWJobHuntResearch  \
# Respondent
# 1793        Read company media, such as employee blogs or ...
# 3072        Read company media, such as employee blogs or ...
# 3045        Company reviews from third party sites (e.g. G...
# 1413        Read company media, such as employee blogs or ...
# 3261        Read company media, such as employee blogs or ...
# 57863       Read company media, such as employee blogs or ...
# 3236        Read company media, such as employee blogs or ...
# 3179        Company reviews from third party sites (e.g. G...
# 3177        Read company media, such as employee blogs or ...
# 1589        Read company media, such as employee blogs or ...
#
#                         NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# Respondent
# 1793                 Once a year          No            Yes            No
# 3072                 Once a year          No             No            No
# 3045            Every few months          No             No            No
# 1413                         NaN         Yes            Yes            No
# 3261        Once every few years          No             No            No
# 57863           Every few months    Not sure            Yes            No
# 3236        Once every few years    Not sure            Yes            No
# 3179                 Once a year    Not sure             No           Yes
# 3177        Once every few years         Yes             No            No
# 1589        Once every few years    Not sure            Yes            No
#
#                                                   NEWOvertime  \
# Respondent
# 1793                        Rarely: 1-2 days per year or less
# 3072        Sometimes: 1-2 days per month but less than we...
# 3045        Sometimes: 1-2 days per month but less than we...
# 1413        Occasionally: 1-2 days per quarter but less th...
# 3261                         Often: 1-2 days per week or more
# 57863                                                   Never
# 3236                                                    Never
# 3179        Sometimes: 1-2 days per month but less than we...
# 3177        Sometimes: 1-2 days per month but less than we...
# 1589        Occasionally: 1-2 days per quarter but less th...
#
#                                           NEWPurchaseResearch  \
# Respondent
# 1793                                                      NaN
# 3072        Start a free trial;Ask developers I know/work ...
# 3045                                                      NaN
# 1413        Start a free trial;Ask developers I know/work ...
# 3261          Visit developer communities like Stack Overflow
# 57863                                                     NaN
# 3236                                                      NaN
# 3179        Start a free trial;Ask developers I know/work ...
# 3177                                                      NaN
# 1589                                                      NaN
#
#                 NEWPurpleLink  \
# Respondent
# 1793        Hello, old friend
# 3072        Hello, old friend
# 3045                   Amused
# 1413        Hello, old friend
# 3261        Hello, old friend
# 57863                     NaN
# 3236                  Annoyed
# 3179        Hello, old friend
# 3177              Indifferent
# 1589              Indifferent
#
#                                                    NEWSOSites  \
# Respondent
# 1793        Stack Overflow (public Q&A for anyone who code...
# 3072        Stack Overflow (public Q&A for anyone who code...
# 3045        Stack Overflow (public Q&A for anyone who code...
# 1413        Stack Overflow (public Q&A for anyone who code...
# 3261        Stack Overflow (public Q&A for anyone who code...
# 57863        Stack Overflow (public Q&A for anyone who codes)
# 3236        Stack Overflow (public Q&A for anyone who code...
# 3179        Stack Overflow (public Q&A for anyone who code...
# 3177        Stack Overflow (public Q&A for anyone who code...
# 1589         Stack Overflow (public Q&A for anyone who codes)
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1793        Call a coworker or friend;Visit Stack Overflow...  Linux-based
# 3072        Meditate;Play games;Call a coworker or friend;...      Windows
# 3045        Play games;Visit Stack Overflow;Go for a walk ...      Windows
# 1413        Play games;Call a coworker or friend;Visit Sta...      Windows
# 3261        Play games;Call a coworker or friend;Visit Sta...        MacOS
# 57863       Call a coworker or friend;Do other work and co...  Linux-based
# 3236        Meditate;Call a coworker or friend;Visit Stack...      Windows
# 3179        Visit Stack Overflow;Go for a walk or other ph...      Windows
# 3177        Meditate;Play games;Call a coworker or friend;...      Windows
# 1589        Visit Stack Overflow;Watch help / tutorial videos      Windows
#
#                              OrgSize  \
# Respondent
# 1793        1,000 to 4,999 employees
# 3072        10,000 or more employees
# 3045            100 to 499 employees
# 1413            500 to 999 employees
# 3261            100 to 499 employees
# 57863       10,000 or more employees
# 3236        1,000 to 4,999 employees
# 3179            500 to 999 employees
# 3177        10,000 or more employees
# 1589            500 to 999 employees
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1793                                          Android;Arduino
# 3072                                     Docker;Linux;Windows
# 3045        Android;AWS;iOS;Kubernetes;Linux;MacOS;Microso...
# 1413                               Linux;Raspberry Pi;Windows
# 3261                                           AWS;Kubernetes
# 57863                     Android;Google Cloud Platform;Linux
# 3236                                                  Windows
# 3179                       Android;Linux;Raspberry Pi;Windows
# 3177                                                      NaN
# 1589        Android;Google Cloud Platform;IBM Cloud or Watson
#
#                                          PlatformWorkedWith  \
# Respondent
# 1793                              Docker;Linux;Raspberry Pi
# 3072                                   Docker;Linux;Windows
# 3045        Android;AWS;Linux;MacOS;Microsoft Azure;Windows
# 1413                   Linux;Raspberry Pi;Windows;WordPress
# 3261                                                    AWS
# 57863                                 Android;Linux;Windows
# 3236                                                Windows
# 3179                 Android;iOS;Linux;Raspberry Pi;Windows
# 3177                                     AWS;Docker;Windows
# 1589                                                Windows
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 1793           I have little or no influence  Straight / Heterosexual
# 3072                   I have some influence  Straight / Heterosexual
# 3045           I have little or no influence  Straight / Heterosexual
# 1413                   I have some influence                 Bisexual
# 3261                                     NaN  Straight / Heterosexual
# 57863          I have little or no influence                      NaN
# 3236           I have little or no influence  Straight / Heterosexual
# 3179        I have a great deal of influence                 Bisexual
# 3177           I have little or no influence  Straight / Heterosexual
# 1589           I have little or no influence  Straight / Heterosexual
#
#            SOAccount           SOComm  \
# Respondent
# 1793             Yes   No, not really
# 3072             Yes  Yes, definitely
# 3045             Yes    Yes, somewhat
# 1413             Yes   No, not really
# 3261             Yes  Yes, definitely
# 57863            Yes   No, not really
# 3236             Yes   No, not really
# 3179             Yes    Yes, somewhat
# 3177             Yes    Yes, somewhat
# 1589             Yes          Neutral
#
#                                                    SOPartFreq  \
# Respondent
# 1793        I have never participated in Q&A on Stack Over...
# 3072                          A few times per month or weekly
# 3045                      Less than once per month or monthly
# 1413                      Less than once per month or monthly
# 3261        I have never participated in Q&A on Stack Over...
# 57863       I have never participated in Q&A on Stack Over...
# 3236                      Less than once per month or monthly
# 3179                          A few times per month or weekly
# 3177                          A few times per month or weekly
# 1589        I have never participated in Q&A on Stack Over...
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 1793                  Daily or almost daily                        Easy
# 3072        A few times per month or weekly                        Easy
# 3045        A few times per month or weekly  Neither easy nor difficult
# 1413                  Daily or almost daily  Neither easy nor difficult
# 3261                   A few times per week                        Easy
# 57863                  A few times per week                        Easy
# 3236                 Multiple times per day                        Easy
# 3179                   A few times per week  Neither easy nor difficult
# 3177                 Multiple times per day                        Easy
# 1589        A few times per month or weekly                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 1793        Appropriate in length    No
# 3072        Appropriate in length    No
# 3045                     Too long    No
# 1413        Appropriate in length    No
# 3261        Appropriate in length    No
# 57863       Appropriate in length    No
# 3236                     Too long    No
# 3179        Appropriate in length    No
# 3177        Appropriate in length    No
# 1589        Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 1793        Computer science, computer engineering, or sof...
# 3072        Computer science, computer engineering, or sof...
# 3045        Computer science, computer engineering, or sof...
# 1413        Computer science, computer engineering, or sof...
# 3261        Computer science, computer engineering, or sof...
# 57863       Computer science, computer engineering, or sof...
# 3236        Computer science, computer engineering, or sof...
# 3179        Computer science, computer engineering, or sof...
# 3177        Computer science, computer engineering, or sof...
# 1589                                                      NaN
#
#                                        WebframeDesireNextYear  \
# Respondent
# 1793                                                      NaN
# 3072                                       ASP.NET Core;Flask
# 3045        Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 1413                                           jQuery;Laravel
# 3261                                     Django;jQuery;Spring
# 57863                                                     NaN
# 3236                              ASP.NET;ASP.NET Core;jQuery
# 3179                                     Angular;ASP.NET Core
# 3177                                  Angular;React.js;Vue.js
# 1589                                                      NaN
#
#                                            WebframeWorkedWith  \
# Respondent
# 1793                                                      NaN
# 3072                                             ASP.NET Core
# 3045        Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 1413                                                   jQuery
# 3261                                                   Spring
# 57863                                                     NaN
# 3236                              ASP.NET;ASP.NET Core;jQuery
# 3179                             Angular;ASP.NET;ASP.NET Core
# 3177                                          Angular;Express
# 1589                                                      NaN
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1793         Just as welcome now as I felt last year         40.0        12
# 3072        Somewhat less welcome now than last year         40.0        10
# 3045         Just as welcome now as I felt last year         42.0        23
# 1413         Just as welcome now as I felt last year         37.0        13
# 3261         Just as welcome now as I felt last year         60.0        11
# 57863        Just as welcome now as I felt last year         40.0         5
# 3236         Just as welcome now as I felt last year         40.0         6
# 3179         Just as welcome now as I felt last year         40.0        17
# 3177         Just as welcome now as I felt last year         40.0        30
# 1589        Somewhat more welcome now than last year          NaN        14
#
#                 YearsCodePro
# Respondent
# 1793                     NaN
# 3072                       7
# 3045                       5
# 1413                       3
# 3261                       9
# 57863       Less than 1 year
# 3236                       3
# 3179                      10
# 3177                      24
# 1589                      14
